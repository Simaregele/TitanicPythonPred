# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('test.csv', header=0, sep=',', 
                 index_col='PassengerId')

# %%
df = pd.read_csv('train.csv', header=0, sep=',', 
                 index_col='PassengerId')

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# 30                  0       3
# ...               ...     ...
# 862                 0       2
# 863                 1       1
# 864                 0       3
# 865                 0       2
# 866                 1       2
# 867                 1       2
# 868                 0       1
# 869                 0       3
# 870                 1       3
# 871                 0       3
# 872                 1       1
# 873                 0       1
# 874                 0       3
# 875                 1       2
# 876                 1       3
# 877                 0       3
# 878                 0       3
# 879                 0       3
# 880                 1       1
# 881                 1       2
# 882                 0       3
# 883                 0       3
# 884                 0       2
# 885                 0       3
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  NaN  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0
# 3                                       Heikkinen, Miss. Laina  NaN  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  NaN  35.0
# 5                                     Allen, Mr. William Henry  NaN  35.0
# 6                                             Moran, Mr. James  NaN   NaN
# 7                                      McCarthy, Mr. Timothy J  NaN  54.0
# 8                               Palsson, Master. Gosta Leonard  NaN   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  NaN  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  NaN  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  NaN   4.0
# 12                                    Bonnell, Miss. Elizabeth  NaN  58.0
# 13                              Saundercock, Mr. William Henry  NaN  20.0
# 14                                 Andersson, Mr. Anders Johan  NaN  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  NaN  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   NaN  55.0
# 17                                        Rice, Master. Eugene  NaN   2.0
# 18                                Williams, Mr. Charles Eugene  NaN   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  NaN  31.0
# 20                                     Masselmani, Mrs. Fatima  NaN   NaN
# 21                                        Fynney, Mr. Joseph J  NaN  35.0
# 22                                       Beesley, Mr. Lawrence  NaN  34.0
# 23                                 McGowan, Miss. Anna "Annie"  NaN  15.0
# 24                                Sloper, Mr. William Thompson  NaN  28.0
# 25                               Palsson, Miss. Torborg Danira  NaN   8.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  NaN  38.0
# 27                                     Emir, Mr. Farred Chehab  NaN   NaN
# 28                              Fortune, Mr. Charles Alexander  NaN  19.0
# 29                               O'Dwyer, Miss. Ellen "Nellie"  NaN   NaN
# 30                                         Todoroff, Mr. Lalio  NaN   NaN
# ...                                                        ...  ...   ...
# 862                                Giles, Mr. Frederick Edward  NaN  21.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  NaN  48.0
# 864                          Sage, Miss. Dorothy Edith "Dolly"  NaN   NaN
# 865                                     Gill, Mr. John William  NaN  24.0
# 866                                   Bystrom, Mrs. (Karolina)  NaN  42.0
# 867                               Duran y More, Miss. Asuncion  NaN  27.0
# 868                       Roebling, Mr. Washington Augustus II  NaN  31.0
# 869                                van Melkebeke, Mr. Philemon  NaN   NaN
# 870                            Johnson, Master. Harold Theodor  NaN   4.0
# 871                                          Balkic, Mr. Cerin  NaN  26.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  NaN  47.0
# 873                                   Carlsson, Mr. Frans Olof  NaN  33.0
# 874                                Vander Cruyssen, Mr. Victor  NaN  47.0
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)  NaN  28.0
# 876                           Najib, Miss. Adele Kiamie "Jane"  NaN  15.0
# 877                              Gustafsson, Mr. Alfred Ossian  NaN  20.0
# 878                                       Petroff, Mr. Nedelio  NaN  19.0
# 879                                         Laleff, Mr. Kristo  NaN   NaN
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  NaN  56.0
# 881               Shelley, Mrs. William (Imanita Parrish Hall)  NaN  25.0
# 882                                         Markun, Mr. Johann  NaN  33.0
# 883                               Dahlberg, Miss. Gerda Ulrika  NaN  22.0
# 884                              Banfield, Mr. Frederick James  NaN  28.0
# 885                                     Sutehall, Mr. Henry Jr  NaN  25.0
# 886                       Rice, Mrs. William (Margaret Norton)  NaN  39.0
# 887                                      Montvila, Rev. Juozas  NaN  27.0
# 888                               Graham, Miss. Margaret Edith  NaN  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  NaN   NaN
# 890                                      Behr, Mr. Karl Howell  NaN  26.0
# 891                                        Dooley, Mr. Patrick  NaN  32.0
#
#              SibSp  Parch            Ticket      Fare        Cabin  Embarked
# PassengerId
# 1                1      0         A/5 21171    7.2500          NaN       2.0
# 2                1      0          PC 17599   71.2833          C85       0.0
# 3                0      0  STON/O2. 3101282    7.9250          NaN       2.0
# 4                1      0            113803   53.1000         C123       2.0
# 5                0      0            373450    8.0500          NaN       2.0
# 6                0      0            330877    8.4583          NaN       1.0
# 7                0      0             17463   51.8625          E46       2.0
# 8                3      1            349909   21.0750          NaN       2.0
# 9                0      2            347742   11.1333          NaN       2.0
# 10               1      0            237736   30.0708          NaN       0.0
# 11               1      1           PP 9549   16.7000           G6       2.0
# 12               0      0            113783   26.5500         C103       2.0
# 13               0      0         A/5. 2151    8.0500          NaN       2.0
# 14               1      5            347082   31.2750          NaN       2.0
# 15               0      0            350406    7.8542          NaN       2.0
# 16               0      0            248706   16.0000          NaN       2.0
# 17               4      1            382652   29.1250          NaN       1.0
# 18               0      0            244373   13.0000          NaN       2.0
# 19               1      0            345763   18.0000          NaN       2.0
# 20               0      0              2649    7.2250          NaN       0.0
# 21               0      0            239865   26.0000          NaN       2.0
# 22               0      0            248698   13.0000          D56       2.0
# 23               0      0            330923    8.0292          NaN       1.0
# 24               0      0            113788   35.5000           A6       2.0
# 25               3      1            349909   21.0750          NaN       2.0
# 26               1      5            347077   31.3875          NaN       2.0
# 27               0      0              2631    7.2250          NaN       0.0
# 28               3      2             19950  263.0000  C23 C25 C27       2.0
# 29               0      0            330959    7.8792          NaN       1.0
# 30               0      0            349216    7.8958          NaN       2.0
# ...            ...    ...               ...       ...          ...       ...
# 862              1      0             28134   11.5000          NaN       2.0
# 863              0      0             17466   25.9292          D17       2.0
# 864              8      2          CA. 2343   69.5500          NaN       2.0
# 865              0      0            233866   13.0000          NaN       2.0
# 866              0      0            236852   13.0000          NaN       2.0
# 867              1      0     SC/PARIS 2149   13.8583          NaN       0.0
# 868              0      0          PC 17590   50.4958          A24       2.0
# 869              0      0            345777    9.5000          NaN       2.0
# 870              1      1            347742   11.1333          NaN       2.0
# 871              0      0            349248    7.8958          NaN       2.0
# 872              1      1             11751   52.5542          D35       2.0
# 873              0      0               695    5.0000  B51 B53 B55       2.0
# 874              0      0            345765    9.0000          NaN       2.0
# 875              1      0         P/PP 3381   24.0000          NaN       0.0
# 876              0      0              2667    7.2250          NaN       0.0
# 877              0      0              7534    9.8458          NaN       2.0
# 878              0      0            349212    7.8958          NaN       2.0
# 879              0      0            349217    7.8958          NaN       2.0
# 880              0      1             11767   83.1583          C50       0.0
# 881              0      1            230433   26.0000          NaN       2.0
# 882              0      0            349257    7.8958          NaN       2.0
# 883              0      0              7552   10.5167          NaN       2.0
# 884              0      0  C.A./SOTON 34068   10.5000          NaN       2.0
# 885              0      0   SOTON/OQ 392076    7.0500          NaN       2.0
# 886              0      5            382652   29.1250          NaN       1.0
# 887              0      0            211536   13.0000          NaN       2.0
# 888              0      0            112053   30.0000          B42       2.0
# 889              1      2        W./C. 6607   23.4500          NaN       2.0
# 890              0      0            111369   30.0000         C148       0.0
# 891              0      0            370376    7.7500          NaN       1.0
#
# [891 rows x 11 columns]>

# %%
print(df.shape)
# Out:
# (891, 11)

# %%
df.shape
# Out:
# (891, 11)

# %%
df.describe()
# Out:
#          Survived      Pclass  Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  0.0  714.000000  891.000000  891.000000
# mean     0.383838    2.308642  NaN   29.699118    0.523008    0.381594
# std      0.486592    0.836071  NaN   14.526497    1.102743    0.806057
# min      0.000000    1.000000  NaN    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000  NaN   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000  NaN   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000  NaN   38.000000    1.000000    0.000000
# max      1.000000    3.000000  NaN   80.000000    8.000000    6.000000
#
#              Fare    Embarked
# count  891.000000  889.000000
# mean    32.204208    1.535433
# std     49.693429    0.792088
# min      0.000000    0.000000
# 25%      7.910400    1.000000
# 50%     14.454200    2.000000
# 75%     31.000000    2.000000
# max    512.329200    2.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(df.corr());

# %% [markdown]
# заменим пол 1- женщина 0-мужчина

# %%
data = { 'male' : 0, 'female': 1}
df['Sex'] = df['Sex'].map(data)

# %% [markdown]
# C = Cherbourg = 0, Q = Queenstown = 1, S = Southampton = 2

# %%
def value(val):
    if val == 'C':
        return 0
    elif val == 'Q':
        return 1
    elif val == 'S':
        return 2

# %%
embark = [value(val) for val in df['Embarked']]

# %%
df['Embarked'] = embark

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN       2.0
# 2                1      0          PC 17599  71.2833   C85       0.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN       2.0
# 4                1      0            113803  53.1000  C123       2.0
# 5                0      0            373450   8.0500   NaN       2.0

# %% [markdown]
# Заменим порты на столбцы с призаками

# %% [markdown]
# C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# Просто вспомнил как эту хрень делать

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(df, alpha=0.4, figsize=(16, 16));
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# mosaic plot

# %%
from statsmodels.graphics.mosaicplot import mosaic

# %%
mosaic(df, ['Survived', 'Sex', 'Pclass'], axes_label=True);

# %%
df['Embarked'].value_counts()
# Out:
# 2.0    644
# 0.0    168
# 1.0     77
# Name: Embarked, dtype: int64

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN       2.0
# 2                1      0          PC 17599  71.2833   C85       0.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN       2.0
# 4                1      0            113803  53.1000  C123       2.0
# 5                0      0            373450   8.0500   NaN       2.0

# %%
df['Fare'].hist();

# %%
import seaborn as sns

# %%
df.groupby('Survived').mean()

# %%
df["Cabin"].value_counts()
# Out:
# G6                 4
# C23 C25 C27        4
# B96 B98            4
# F2                 3
# C22 C26            3
# F33                3
# D                  3
# E101               3
# B51 B53 B55        2
# C83                2
# B49                2
# D26                2
# E25                2
# B77                2
# C123               2
# C52                2
# C78                2
# D33                2
# F G73              2
# C126               2
# E24                2
# B22                2
# C92                2
# B57 B59 B63 B66    2
# E44                2
# B28                2
# C2                 2
# E67                2
# B5                 2
# D17                2
#                   ..
# A23                1
# B69                1
# E31                1
# E49                1
# C70                1
# B78                1
# A36                1
# D37                1
# D9                 1
# A10                1
# B30                1
# D28                1
# D49                1
# B39                1
# C95                1
# C62 C64            1
# E34                1
# C128               1
# A14                1
# E17                1
# D21                1
# C50                1
# C99                1
# A19                1
# D46                1
# E40                1
# C104               1
# B102               1
# B82 B84            1
# A34                1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
df['Age'].isna().value_counts()
# Out:
# False    714
# True     177
# Name: Age, dtype: int64

# %%
df['Cabin'].isna().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
df['Embarked'].isna().value_counts()
# Out:
# False    889
# True       2
# Name: Embarked, dtype: int64

# %%
# заменю пропуски в cabin на NA 0

# %%
col = pd.Series(df["Cabin"])

# %%
result = col.str.extract('([a-zA-Z]+)([^a-zA-Z]+)', expand=True)
result.columns = ['CabinStr', 'CabinNum']

# %%
df['CabinStr'] = result["CabinStr"]

# %%
df['CabinNum'] = result["CabinNum"]

# %%
df['CabinStr'].value_counts()
# Out:
# C    59
# B    47
# E    32
# D    30
# A    15
# F    13
# G     4
# Name: CabinStr, dtype: int64

# %%
df['CabinStr'] = df['CabinStr'].fillna('Z')

# %%
df['CabinNum'] = df['CabinNum'].fillna(0)

# %%
df['Embarked'].value_counts()
# Out:
# 2.0    644
# 0.0    168
# 1.0     77
# Name: Embarked, dtype: int64

# %%
# fill na by median

# %%
df['Embarked'] = df['Embarked'].fillna(2)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# 30                  0       3
# ...               ...     ...
# 862                 0       2
# 863                 1       1
# 864                 0       3
# 865                 0       2
# 866                 1       2
# 867                 1       2
# 868                 0       1
# 869                 0       3
# 870                 1       3
# 871                 0       3
# 872                 1       1
# 873                 0       1
# 874                 0       3
# 875                 1       2
# 876                 1       3
# 877                 0       3
# 878                 0       3
# 879                 0       3
# 880                 1       1
# 881                 1       2
# 882                 0       3
# 883                 0       3
# 884                 0       2
# 885                 0       3
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# 6                                             Moran, Mr. James    0   NaN
# 7                                      McCarthy, Mr. Timothy J    0  54.0
# 8                               Palsson, Master. Gosta Leonard    0   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)    1  14.0
# 11                             Sandstrom, Miss. Marguerite Rut    1   4.0
# 12                                    Bonnell, Miss. Elizabeth    1  58.0
# 13                              Saundercock, Mr. William Henry    0  20.0
# 14                                 Andersson, Mr. Anders Johan    0  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina    1  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)     1  55.0
# 17                                        Rice, Master. Eugene    0   2.0
# 18                                Williams, Mr. Charles Eugene    0   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...    1  31.0
# 20                                     Masselmani, Mrs. Fatima    1   NaN
# 21                                        Fynney, Mr. Joseph J    0  35.0
# 22                                       Beesley, Mr. Lawrence    0  34.0
# 23                                 McGowan, Miss. Anna "Annie"    1  15.0
# 24                                Sloper, Mr. William Thompson    0  28.0
# 25                               Palsson, Miss. Torborg Danira    1   8.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...    1  38.0
# 27                                     Emir, Mr. Farred Chehab    0   NaN
# 28                              Fortune, Mr. Charles Alexander    0  19.0
# 29                               O'Dwyer, Miss. Ellen "Nellie"    1   NaN
# 30                                         Todoroff, Mr. Lalio    0   NaN
# ...                                                        ...  ...   ...
# 862                                Giles, Mr. Frederick Edward    0  21.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...    1  48.0
# 864                          Sage, Miss. Dorothy Edith "Dolly"    1   NaN
# 865                                     Gill, Mr. John William    0  24.0
# 866                                   Bystrom, Mrs. (Karolina)    1  42.0
# 867                               Duran y More, Miss. Asuncion    1  27.0
# 868                       Roebling, Mr. Washington Augustus II    0  31.0
# 869                                van Melkebeke, Mr. Philemon    0   NaN
# 870                            Johnson, Master. Harold Theodor    0   4.0
# 871                                          Balkic, Mr. Cerin    0  26.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)    1  47.0
# 873                                   Carlsson, Mr. Frans Olof    0  33.0
# 874                                Vander Cruyssen, Mr. Victor    0  47.0
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)    1  28.0
# 876                           Najib, Miss. Adele Kiamie "Jane"    1  15.0
# 877                              Gustafsson, Mr. Alfred Ossian    0  20.0
# 878                                       Petroff, Mr. Nedelio    0  19.0
# 879                                         Laleff, Mr. Kristo    0   NaN
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    1  56.0
# 881               Shelley, Mrs. William (Imanita Parrish Hall)    1  25.0
# 882                                         Markun, Mr. Johann    0  33.0
# 883                               Dahlberg, Miss. Gerda Ulrika    1  22.0
# 884                              Banfield, Mr. Frederick James    0  28.0
# 885                                     Sutehall, Mr. Henry Jr    0  25.0
# 886                       Rice, Mrs. William (Margaret Norton)    1  39.0
# 887                                      Montvila, Rev. Juozas    0  27.0
# 888                               Graham, Miss. Margaret Edith    1  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"    1   NaN
# 890                                      Behr, Mr. Karl Howell    0  26.0
# 891                                        Dooley, Mr. Patrick    0  32.0
#
#              SibSp  Parch            Ticket      Fare        Cabin  Embarked  \
# PassengerId
# 1                1      0         A/5 21171    7.2500          NaN       2.0
# 2                1      0          PC 17599   71.2833          C85       0.0
# 3                0      0  STON/O2. 3101282    7.9250          NaN       2.0
# 4                1      0            113803   53.1000         C123       2.0
# 5                0      0            373450    8.0500          NaN       2.0
# 6                0      0            330877    8.4583          NaN       1.0
# 7                0      0             17463   51.8625          E46       2.0
# 8                3      1            349909   21.0750          NaN       2.0
# 9                0      2            347742   11.1333          NaN       2.0
# 10               1      0            237736   30.0708          NaN       0.0
# 11               1      1           PP 9549   16.7000           G6       2.0
# 12               0      0            113783   26.5500         C103       2.0
# 13               0      0         A/5. 2151    8.0500          NaN       2.0
# 14               1      5            347082   31.2750          NaN       2.0
# 15               0      0            350406    7.8542          NaN       2.0
# 16               0      0            248706   16.0000          NaN       2.0
# 17               4      1            382652   29.1250          NaN       1.0
# 18               0      0            244373   13.0000          NaN       2.0
# 19               1      0            345763   18.0000          NaN       2.0
# 20               0      0              2649    7.2250          NaN       0.0
# 21               0      0            239865   26.0000          NaN       2.0
# 22               0      0            248698   13.0000          D56       2.0
# 23               0      0            330923    8.0292          NaN       1.0
# 24               0      0            113788   35.5000           A6       2.0
# 25               3      1            349909   21.0750          NaN       2.0
# 26               1      5            347077   31.3875          NaN       2.0
# 27               0      0              2631    7.2250          NaN       0.0
# 28               3      2             19950  263.0000  C23 C25 C27       2.0
# 29               0      0            330959    7.8792          NaN       1.0
# 30               0      0            349216    7.8958          NaN       2.0
# ...            ...    ...               ...       ...          ...       ...
# 862              1      0             28134   11.5000          NaN       2.0
# 863              0      0             17466   25.9292          D17       2.0
# 864              8      2          CA. 2343   69.5500          NaN       2.0
# 865              0      0            233866   13.0000          NaN       2.0
# 866              0      0            236852   13.0000          NaN       2.0
# 867              1      0     SC/PARIS 2149   13.8583          NaN       0.0
# 868              0      0          PC 17590   50.4958          A24       2.0
# 869              0      0            345777    9.5000          NaN       2.0
# 870              1      1            347742   11.1333          NaN       2.0
# 871              0      0            349248    7.8958          NaN       2.0
# 872              1      1             11751   52.5542          D35       2.0
# 873              0      0               695    5.0000  B51 B53 B55       2.0
# 874              0      0            345765    9.0000          NaN       2.0
# 875              1      0         P/PP 3381   24.0000          NaN       0.0
# 876              0      0              2667    7.2250          NaN       0.0
# 877              0      0              7534    9.8458          NaN       2.0
# 878              0      0            349212    7.8958          NaN       2.0
# 879              0      0            349217    7.8958          NaN       2.0
# 880              0      1             11767   83.1583          C50       0.0
# 881              0      1            230433   26.0000          NaN       2.0
# 882              0      0            349257    7.8958          NaN       2.0
# 883              0      0              7552   10.5167          NaN       2.0
# 884              0      0  C.A./SOTON 34068   10.5000          NaN       2.0
# 885              0      0   SOTON/OQ 392076    7.0500          NaN       2.0
# 886              0      5            382652   29.1250          NaN       1.0
# 887              0      0            211536   13.0000          NaN       2.0
# 888              0      0            112053   30.0000          B42       2.0
# 889              1      2        W./C. 6607   23.4500          NaN       2.0
# 890              0      0            111369   30.0000         C148       0.0
# 891              0      0            370376    7.7500          NaN       1.0
#
#             CabinStr CabinNum
# PassengerId
# 1                  Z        0
# 2                  C       85
# 3                  Z        0
# 4                  C      123
# 5                  Z        0
# 6                  Z        0
# 7                  E       46
# 8                  Z        0
# 9                  Z        0
# 10                 Z        0
# 11                 G        6
# 12                 C      103
# 13                 Z        0
# 14                 Z        0
# 15                 Z        0
# 16                 Z        0
# 17                 Z        0
# 18                 Z        0
# 19                 Z        0
# 20                 Z        0
# 21                 Z        0
# 22                 D       56
# 23                 Z        0
# 24                 A        6
# 25                 Z        0
# 26                 Z        0
# 27                 Z        0
# 28                 C      23
# 29                 Z        0
# 30                 Z        0
# ...              ...      ...
# 862                Z        0
# 863                D       17
# 864                Z        0
# 865                Z        0
# 866                Z        0
# 867                Z        0
# 868                A       24
# 869                Z        0
# 870                Z        0
# 871                Z        0
# 872                D       35
# 873                B      51
# 874                Z        0
# 875                Z        0
# 876                Z        0
# 877                Z        0
# 878                Z        0
# 879                Z        0
# 880                C       50
# 881                Z        0
# 882                Z        0
# 883                Z        0
# 884                Z        0
# 885                Z        0
# 886                Z        0
# 887                Z        0
# 888                B       42
# 889                Z        0
# 890                C      148
# 891                Z        0
#
# [891 rows x 13 columns]

# %%
# age na replace by mean()

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df['Age'].isna().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Cabin'], dtype='object')

# %%
df = df.drop(columns=['Cabin'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null int64
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null float64
# CabinStr    891 non-null category
# CabinNum    891 non-null int64
# dtypes: category(1), float64(3), int64(6), object(2)
# memory usage: 124.8+ KB

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df['CabinNum'] = df['CabinNum'].str.strip()

# %%
df['CabinNum'] = df['CabinNum'].fillna(0)

# %%
df['CabinNum'] = df['CabinNum'].replace('', 0)

# %%
df['CabinNum'] = df['CabinNum'].replace(' ', 0)

# %%
df['CabinStr'] = df['CabinStr'].astype('category')

# %%
df['CabinNum'] = df['CabinNum'].astype('int64')

# %%
df['CabinStr'].value_counts()
# Out:
# Z    691
# C     59
# B     47
# E     32
# D     30
# A     15
# F     13
# G      4
# Name: CabinStr, dtype: int64

# %%
value_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'Z':10}

# %%
df['CabinStr'] = df['CabinStr'].map(value_map)

# %%
df['CabinStr'] = df['CabinStr'].astype('category')

# %%
df['CabinStr']
# Out:
# PassengerId
# 1      10
# 2       2
# 3      10
# 4       2
# 5      10
# 6      10
# 7       4
# 8      10
# 9      10
# 10     10
# 11      6
# 12      2
# 13     10
# 14     10
# 15     10
# 16     10
# 17     10
# 18     10
# 19     10
# 20     10
# 21     10
# 22      3
# 23     10
# 24      0
# 25     10
# 26     10
# 27     10
# 28      2
# 29     10
# 30     10
#        ..
# 862    10
# 863     3
# 864    10
# 865    10
# 866    10
# 867    10
# 868     0
# 869    10
# 870    10
# 871    10
# 872     3
# 873     1
# 874    10
# 875    10
# 876    10
# 877    10
# 878    10
# 879    10
# 880     2
# 881    10
# 882    10
# 883    10
# 884    10
# 885    10
# 886    10
# 887    10
# 888     1
# 889    10
# 890     2
# 891    10
# Name: CabinStr, Length: 891, dtype: category
# Categories (8, int64): [0, 1, 2, 3, 4, 5, 6, 10]

# %% [markdown]
# Поделим данные на трэйн тест

# %%
df_targ = df['Survived']
df_data = df.drop(columns=["Survived"])

# %%
df_data = df_data.select_dtypes(exclude=['object'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df_data, df_targ, test_size=0.33, random_state=42)

# %% [markdown]
# regression lets try it

# %%
y_test
# Out:
# PassengerId
# 710    1
# 440    0
# 841    0
# 721    1
# 40     1
# 291    1
# 301    1
# 334    0
# 209    1
# 137    1
# 138    0
# 697    0
# 486    0
# 245    0
# 345    0
# 854    1
# 622    1
# 654    1
# 887    0
# 111    0
# 295    0
# 448    1
# 193    1
# 683    0
# 539    0
# 820    0
# 31     0
# 674    1
# 64     0
# 397    0
#       ..
# 457    0
# 501    0
# 431    1
# 446    1
# 651    0
# 173    1
# 451    0
# 315    0
# 333    0
# 802    1
# 91     0
# 835    0
# 182    0
# 582    1
# 796    0
# 70     0
# 132    0
# 335    1
# 598    0
# 136    0
# 165    0
# 29     1
# 784    0
# 194    1
# 870    1
# 716    0
# 526    0
# 382    1
# 141    0
# 174    0
# Name: Survived, Length: 295, dtype: int64

# %%
logreg = LogisticRegression(solver='liblinear', random_state=0)

# %%
X_train
# Out:
#              Pclass  Sex        Age  SibSp  Parch      Fare  Embarked  \
# PassengerId
# 7                 1    0  54.000000      0      0   51.8625       2.0
# 719               3    0  29.699118      0      0   15.5000       1.0
# 686               2    0  25.000000      1      2   41.5792       0.0
# 74                3    0  26.000000      1      0   14.4542       0.0
# 883               3    1  22.000000      0      0   10.5167       2.0
# 329               3    1  31.000000      1      1   20.5250       2.0
# 454               1    0  49.000000      1      0   89.1042       0.0
# 146               2    0  19.000000      1      1   36.7500       2.0
# 235               2    0  24.000000      0      0   10.5000       2.0
# 221               3    0  16.000000      0      0    8.0500       2.0
# 371               1    0  25.000000      1      0   55.4417       0.0
# 812               3    0  39.000000      0      0   24.1500       2.0
# 133               3    1  47.000000      1      0   14.5000       2.0
# 695               1    0  60.000000      0      0   26.5500       2.0
# 865               2    0  24.000000      0      0   13.0000       2.0
# 186               1    0  29.699118      0      0   50.0000       2.0
# 42                2    1  27.000000      1      0   21.0000       2.0
# 548               2    0  29.699118      0      0   13.8625       0.0
# 109               3    0  38.000000      0      0    7.8958       2.0
# 604               3    0  44.000000      0      0    8.0500       2.0
# 57                2    1  21.000000      0      0   10.5000       2.0
# 395               3    1  24.000000      0      2   16.7000       2.0
# 707               2    1  45.000000      0      0   13.5000       2.0
# 550               2    0   8.000000      1      1   36.7500       2.0
# 25                3    1   8.000000      3      1   21.0750       2.0
# 352               1    0  29.699118      0      0   35.0000       2.0
# 430               3    0  32.000000      0      0    8.0500       2.0
# 435               1    0  50.000000      1      0   55.9000       2.0
# 52                3    0  21.000000      0      0    7.8000       2.0
# 527               2    1  50.000000      0      0   10.5000       2.0
# ...             ...  ...        ...    ...    ...       ...       ...
# 277               3    1  45.000000      0      0    7.7500       2.0
# 192               2    0  19.000000      0      0   13.0000       2.0
# 386               2    0  18.000000      0      0   73.5000       2.0
# 806               3    0  31.000000      0      0    7.7750       2.0
# 414               2    0  29.699118      0      0    0.0000       2.0
# 492               3    0  21.000000      0      0    7.2500       2.0
# 344               2    0  25.000000      0      0   13.0000       2.0
# 770               3    0  32.000000      0      0    8.3625       2.0
# 309               2    0  30.000000      1      0   24.0000       0.0
# 662               3    0  40.000000      0      0    7.2250       0.0
# 131               3    0  33.000000      0      0    7.8958       0.0
# 664               3    0  36.000000      0      0    7.4958       2.0
# 872               1    1  47.000000      1      1   52.5542       2.0
# 100               2    0  34.000000      1      0   26.0000       2.0
# 373               3    0  19.000000      0      0    8.0500       2.0
# 88                3    0  29.699118      0      0    8.0500       2.0
# 459               2    1  50.000000      0      0   10.5000       2.0
# 331               3    1  29.699118      2      0   23.2500       1.0
# 215               3    0  29.699118      1      0    7.7500       1.0
# 467               2    0  29.699118      0      0    0.0000       2.0
# 122               3    0  29.699118      0      0    8.0500       2.0
# 615               3    0  35.000000      0      0    8.0500       2.0
# 21                2    0  35.000000      0      0   26.0000       2.0
# 701               1    1  18.000000      1      0  227.5250       0.0
# 72                3    1  16.000000      5      2   46.9000       2.0
# 107               3    1  21.000000      0      0    7.6500       2.0
# 271               1    0  29.699118      0      0   31.0000       2.0
# 861               3    0  41.000000      2      0   14.1083       2.0
# 436               1    1  14.000000      1      2  120.0000       2.0
# 103               1    0  21.000000      0      1   77.2875       2.0
#
#             CabinStr  CabinNum
# PassengerId
# 7                  4        46
# 719               10         0
# 686               10         0
# 74                10         0
# 883               10         0
# 329               10         0
# 454                2        92
# 146               10         0
# 235               10         0
# 221               10         0
# 371                4        50
# 812               10         0
# 133               10         0
# 695               10         0
# 865               10         0
# 186                0        32
# 42                10         0
# 548               10         0
# 109               10         0
# 604               10         0
# 57                10         0
# 395                6         6
# 707               10         0
# 550               10         0
# 25                10         0
# 352                2       128
# 430                4        10
# 435                4        44
# 52                10         0
# 527               10         0
# ...              ...       ...
# 277               10         0
# 192               10         0
# 386               10         0
# 806               10         0
# 414               10         0
# 492               10         0
# 344               10         0
# 770               10         0
# 309               10         0
# 662               10         0
# 131               10         0
# 664               10         0
# 872                3        35
# 100               10         0
# 373               10         0
# 88                10         0
# 459               10         0
# 331               10         0
# 215               10         0
# 467               10         0
# 122               10         0
# 615               10         0
# 21                10         0
# 701                2        62
# 72                10         0
# 107               10         0
# 271               10         0
# 861               10         0
# 436                1        96
# 103                3        26
#
# [596 rows x 9 columns]

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=logreg.predict(X_test)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[154,  21],
#        [ 33,  87]], dtype=int64)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8169491525423729

# %%
metrics.precision_score(y_test, y_pred)
# Out:
# 0.8055555555555556

# %%
logreg.get_paramst_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'max_iter': 100,
#  'multi_class': 'warn',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 0,
#  'solver': 'liblinear',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred=knn.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7186440677966102

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)
err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)
print(err_train, err_test)
# Out:
# 0.20134228187919462 0.28135593220338984

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7186440677966102
